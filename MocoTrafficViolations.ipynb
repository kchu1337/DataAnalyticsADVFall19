# %%
#Python library used to parse JSON
import json
import pandas as pd

# %%
filepath = "datasets/MoCoViolations_2018.json"

data= {};

with open(filepath) as file:
    data = (json.load(file))

# %%
columnsMeta = data['meta']['view']['columns']
violationsData = data['data']

# %%
# columns = []
# for column in columnsMeta:
#     columns.append(column['name'])
# print(columns)

columns = list(map(lambda column: column['name'], columnsMeta)) 
print(columns)
# Out:
# ['sid', 'id', 'position', 'created_at', 'created_meta', 'updated_at', 'updated_meta', 'meta', 'SeqID', 'Date Of Stop', 'Time Of Stop', 'Agency', 'SubAgency', 'Description', 'Location', 'Latitude', 'Longitude', 'Accident', 'Belts', 'Personal Injury', 'Property Damage', 'Fatal', 'Commercial License', 'HAZMAT', 'Commercial Vehicle', 'Alcohol', 'Work Zone', 'State', 'VehicleType', 'Year', 'Make', 'Model', 'Color', 'Violation Type', 'Charge', 'Article', 'Contributed To Accident', 'Race', 'Gender', 'Driver City', 'Driver State', 'DL State', 'Arrest Type', 'Geolocation', 'Council Districts', 'Councils', 'Communities', 'Zip Codes', 'Municipalities']

# %%
df = pd.DataFrame(violationsData, columns=columns)

# %%
finalDf = df.drop(columns=
             ['sid',
              'id',
              'position',
              'created_at',
              'created_meta',
              'updated_at',
              'updated_meta',
              'meta',
              'SeqID',
              'Accident',
              'Driver City',
              'Belts',
              'Personal Injury',
              'Property Damage',
              'Fatal',
              'Commercial License',
              'HAZMAT',
              'Commercial Vehicle',
              'Alcohol',
              'Work Zone',
              'State',
              'Charge',
              'Article',
              'Contributed To Accident',
              'Geolocation',
              'Council Districts',
              'Councils',
              'Communities',
              'Zip Codes',
              'Municipalities'])
finalDf.head()
# Out:
#           Date Of Stop Time Of Stop Agency  \
# 0  2018-12-31T00:00:00     23:56:00    MCP
# 1  2018-12-31T00:00:00     23:52:00    MCP
# 2  2018-12-31T00:00:00     23:52:00    MCP
# 3  2018-12-31T00:00:00     23:45:00    MCP
# 4  2018-12-31T00:00:00     23:44:00    MCP
#
#                                          SubAgency  \
# 0                          1st District, Rockville
# 1  6th District, Gaithersburg / Montgomery Village
# 2  6th District, Gaithersburg / Montgomery Village
# 3                          1st District, Rockville
# 4              Headquarters and Special Operations
#
#                                          Description  \
# 0  FAILURE OF VEH. ON HWY. TO DISPLAY LIGHTED LAM...
# 1  FAILURE TO DISPLAY TWO LIGHTED FRONT LAMPS WHE...
# 2  FAILURE OF VEH. ON HWY. TO DISPLAY LIGHTED LAM...
# 3  FAILURE OF VEH. ON HWY. TO DISPLAY LIGHTED LAM...
# 4  FAILURE TO DRIVE VEHICLE ON RIGHT HALF OF ROAD...
#
# ...
